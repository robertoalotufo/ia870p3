# %% [markdown]
# # surf - display gray scale image as 3D relief 2D view

# %%
from PIL import Image
import numpy as np
import ia870 as MT

# %%
f_pil = Image.open('data/r4x2_256.tif')
f_pil
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=P size=254x255 at 0x1069102E8>

# %%
f = np.array(f_pil)

# %%
g = MT.iagsurf(f)

# %%
Image.fromarray(g)
# Out:
# <PIL.Image.Image image mode=L size=254x255 at 0x108C58128>
